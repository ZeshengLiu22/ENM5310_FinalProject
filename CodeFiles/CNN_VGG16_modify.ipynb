# %%
import jax
import jax.numpy as np
import numpy as onp
from jax import random, jit, vmap, grad
from jax.experimental import optimizers,stax
from jax.experimental.stax import Dense, Conv, Relu, MaxPool, Flatten, Softmax,BatchNorm,Dropout,AvgPool
from jax.experimental.optimizers import optimizer, make_schedule, exponential_decay
#from jax.ops import index, index_update

import itertools
from functools import partial
from tqdm import trange
from torch.utils import data
import matplotlib.pyplot as plt

from scipy.integrate import odeint

from jax.nn import sigmoid,relu,log_sigmoid,one_hot
from jax.lax import scan
import h5py
from sklearn.metrics import confusion_matrix
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/experimental/optimizers.py:30: FutureWarning: jax.experimental.optimizers is deprecated, import jax.example_libraries.optimizers instead
#   FutureWarning)
# /usr/local/lib/python3.7/dist-packages/jax/experimental/stax.py:30: FutureWarning: jax.experimental.stax is deprecated, import jax.example_libraries.stax instead
#   FutureWarning)

# %%
import functools
import operator as op

from jax import lax
from jax import random
import jax.numpy as jnp

from jax.nn import (relu, log_softmax, softmax, softplus, sigmoid, elu,
                    leaky_relu, selu, gelu)
from jax.nn.initializers import glorot_normal, normal, ones, zeros

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm/ np.sum(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
from keras.datasets import cifar10
import tensorflow as tf

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
class DataGenerator(data.Dataset):
    def __init__(self, images, labels, 
                 batch_size=128, 
                 rng_key=random.PRNGKey(1234)):
        'Initialization'
        self.images = images
        self.labels = labels
        self.N = labels.shape[0]
        self.batch_size = batch_size
        self.key = rng_key

    @partial(jit, static_argnums=(0,))
    def __data_generation(self, key, images, labels):
        'Generates data containing batch_size samples'
        idx = random.choice(key, self.N, (self.batch_size,), replace=False)
        images = images[idx,...]
        labels = labels[idx,...]
        return images, labels

    def __getitem__(self, index):
        'Generate one batch of data'
        self.key, subkey = random.split(self.key)
        images, labels = self.__data_generation(self.key, self.images, self.labels)
        return images, labels

# %%
x_train=np.asarray(x_train)
x_test=np.asarray(x_test)

# %%
x_train=x_train/255.
num_classes=y_train.max()+1
y_train=y_train.flatten()
y_train=one_hot(y_train,num_classes)

print(x_train.shape)
print(y_train.shape)

train_dataset = DataGenerator(x_train, y_train, batch_size=128)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)

# %%
# !pip install --upgrade pip
# !pip install jax[cuda11_cudnn805] -f https://storage.googleapis.com/jax-releases/jax_releases.html
# !pip install --upgrade git+https://github.com/matthias-wright/flaxmodels.git

# %%
import flaxmodels as fm

# %%
vgg=fm.VGG16(num_classes=10,pretrained=None,include_head=False)
net_init, net_apply = vgg.init,vgg.apply
params = net_init(random.PRNGKey(0), np.zeros((128,32,32,3)))

# %%
data=iter(train_dataset)
batch=next(data)
images, labels = batch
outputs = net_apply(params, images,rng=random.PRNGKey(0))
loss = -labels*np.log(outputs+1e-7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in broadcast_shapes(*shapes)
#     120   try:
# --> 121     return _broadcast_shapes_cached(*shapes)
#     122   except:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     209       else:
# --> 210         return cached(config._trace_context(), *args, **kwargs)
#     211
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     202     def cached(_, *args, **kwargs):
# --> 203       return f(*args, **kwargs)
#     204
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_cached(*shapes)
#     126 def _broadcast_shapes_cached(*shapes: Tuple[int, ...]) -> Tuple[int, ...]:
# --> 127   return _broadcast_shapes_uncached(*shapes)
#     128
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     143     raise ValueError("Incompatible shapes for broadcasting: {}"
# --> 144                      .format(tuple(shape_list)))
#     145   return result_shape
#
# ValueError: Incompatible shapes for broadcasting: ((1, 1, 128, 10), (128, 1, 1, 512))
#
# During handling of the above exception, another exception occurred:
#
# UnfilteredStackTrace                      Traceback (most recent call last)
# <ipython-input-34-09a57f3172f9> in <module>()
#       4 outputs = net_apply(params, images,rng=random.PRNGKey(0))
# ----> 5 loss = -labels*np.log(outputs+1e-7)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    5251       return NotImplemented
# -> 5252     return binary_op(self, other)
#    5253   return deferring_binary_op
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     161     try:
# --> 162       return fun(*args, **kwargs)
#     163     except Exception as e:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     434         device=device, backend=backend, name=flat_fun.__name__,
# --> 435         donated_invars=donated_invars, inline=inline)
#     436     out_pytree_def = out_tree()
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, fun, *args, **params)
#    1708   def bind(self, fun, *args, **params):
# -> 1709     return call_bind(self, fun, *args, **params)
#    1710
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1720   tracers = map(top_trace.full_raise, args)
# -> 1721   outs = top_trace.process_call(primitive, fun, tracers, params)
#    1722   return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     613   def process_call(self, primitive, f, tracers, params):
# --> 614     return primitive.impl(f, *tracers, **params)
#     615   process_map = process_call
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/dispatch.py in _xla_call_impl(***failed resolving arguments***)
#     142   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
# --> 143                                *unsafe_map(arg_spec, args))
#     144   try:
#
# /usr/local/lib/python3.7/dist-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     271     else:
# --> 272       ans = call(fun, *args)
#     273       cache[key] = (ans, fun.stores)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/dispatch.py in _xla_callable_uncached(fun, device, backend, name, donated_invars, *arg_specs)
#     169   return lower_xla_callable(fun, device, backend, name, donated_invars,
# --> 170                             *arg_specs).compile().unsafe_call
#     171
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     205     with TraceAnnotation(name, **decorator_kwargs):
# --> 206       return func(*args, **kwargs)
#     207     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/dispatch.py in lower_xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     197     jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(
# --> 198         fun, abstract_args, pe.debug_info_final(fun, "jit"))
#     199   if any(isinstance(c, core.Tracer) for c in consts):
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     205     with TraceAnnotation(name, **decorator_kwargs):
# --> 206       return func(*args, **kwargs)
#     207     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals, debug_info)
#    1797     with core.new_sublevel():
# -> 1798       jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1799     del fun, main
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs)
#    1774     in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 1775     ans = fun.call_wrapped(*in_tracers_)
#    1776     out_tracers = map(trace.full_raise, ans)
#
# /usr/local/lib/python3.7/dist-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/ufuncs.py in fn(x1, x2)
#      85   def fn(x1, x2):
# ---> 86     x1, x2 = _promote_args(numpy_fn.__name__, x1, x2)
#      87     return lax_fn(x1, x2) if x1.dtype != np.bool_ else bool_lax_fn(x1, x2)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/util.py in _promote_args(fun_name, *args)
#     314   _check_no_float0s(fun_name, *args)
# --> 315   return _promote_shapes(fun_name, *_promote_dtypes(*args))
#     316
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/util.py in _promote_shapes(fun_name, *args)
#     223       else:
# --> 224         result_rank = len(lax.broadcast_shapes(*shapes))
#     225         return [_broadcast_to(arg, (1,) * (result_rank - len(shp)) + shp)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in broadcast_shapes(*shapes)
#     122   except:
# --> 123     return _broadcast_shapes_uncached(*shapes)
#     124
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     143     raise ValueError("Incompatible shapes for broadcasting: {}"
# --> 144                      .format(tuple(shape_list)))
#     145   return result_shape
#
# UnfilteredStackTrace: ValueError: Incompatible shapes for broadcasting: ((1, 1, 128, 10), (128, 1, 1, 512))
#
# The stack trace below excludes JAX-internal frames.
# The preceding is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-09a57f3172f9> in <module>()
#       3 images, labels = batch
#       4 outputs = net_apply(params, images,rng=random.PRNGKey(0))
# ----> 5 loss = -labels*np.log(outputs+1e-7)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    5250     if not isinstance(other, _accepted_binop_types):
#    5251       return NotImplemented
# -> 5252     return binary_op(self, other)
#    5253   return deferring_binary_op
#    5254
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/ufuncs.py in fn(x1, x2)
#      84 def _maybe_bool_binop(numpy_fn, lax_fn, bool_lax_fn, lax_doc=False):
#      85   def fn(x1, x2):
# ---> 86     x1, x2 = _promote_args(numpy_fn.__name__, x1, x2)
#      87     return lax_fn(x1, x2) if x1.dtype != np.bool_ else bool_lax_fn(x1, x2)
#      88   fn = jit(fn, inline=True)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/util.py in _promote_args(fun_name, *args)
#     313   _check_arraylike(fun_name, *args)
#     314   _check_no_float0s(fun_name, *args)
# --> 315   return _promote_shapes(fun_name, *_promote_dtypes(*args))
#     316
#     317
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/util.py in _promote_shapes(fun_name, *args)
#     222         return [_broadcast_to(arg, res_shape) for arg, shp in zip(args, shapes)]
#     223       else:
# --> 224         result_rank = len(lax.broadcast_shapes(*shapes))
#     225         return [_broadcast_to(arg, (1,) * (result_rank - len(shp)) + shp)
#     226                 for arg, shp in zip(args, shapes)]
#
# ValueError: Incompatible shapes for broadcasting: ((1, 1, 128, 10), (128, 1, 1, 512))

# %%
images.shape
# Out:
# (128, 32, 32, 3)

# %%
labels.shape
# Out:
# (128, 10)

# %%
outputs.shape
# Out:
# (128, 1, 1, 512)

# %%
class CNNclassifier:
    # Initialize the class
    def __init__(self, rng_key=random.PRNGKey(0)):
        # MLP init and apply functions
        vgg=fm.VGG16(num_classes=10,pretrained=None,include_head=False)
        self.net_init, self.net_apply = vgg.init,vgg.apply
        params = self.net_init(rng_key, np.zeros((128,32,32,3)))

        # Optimizer initialization and update functions
        lr = optimizers.exponential_decay(1e-3, decay_steps=1000, decay_rate=0.999)
        self.opt_init, \
        self.opt_update, \
        self.get_params = optimizers.adam(lr)
        self.opt_state = self.opt_init(params)

        # Logger
        self.itercount = itertools.count()
        self.loss_log = []

    def loss(self, params, batch,it):
        images, labels = batch
        outputs = self.net_apply(params, images,rng=random.PRNGKey(it))
        loss = -labels*np.log(outputs+1e-7)
        return np.mean(loss)

    @partial(jit, static_argnums=(0,))
    def step(self, i, opt_state, batch):
        params = self.get_params(opt_state)
        gradients = grad(self.loss)(params, batch, i)
        return self.opt_update(i, gradients, opt_state)

    def train(self, dataset, nIter = 10):
        data = iter(dataset)
        pbar = trange(nIter)
        # Main training loop
        for it in pbar:
            # Run one gradient descent update
            batch = next(data)
            self.opt_state = self.step(next(self.itercount), self.opt_state, batch)  
            if it % 50 == 0:
                # Logger
                params = self.get_params(self.opt_state)
                loss = self.loss(params, batch,it)
                self.loss_log.append(loss)
                pbar.set_postfix({'Loss': loss})

    @partial(jit, static_argnums=(0,))
    def predict(self, params, inputs):
        outputs = self.net_apply(params, inputs,rng=random.PRNGKey(0))
        return outputs

# %%
# Initialize model
model = CNNclassifier()

# %%
x_test=x_test/255.
num_classes=y_test.max()+1
y_test=y_test.flatten()
y_test=one_hot(y_test,num_classes)
x_test=np.asarray(x_test)
test_dataset = DataGenerator(x_test, y_test, batch_size=128)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (10000, 32, 32, 3)
# (10000, 10)

# %%
# Train model
model.train(train_dataset, nIter=5000)
opt_params = model.get_params(model.opt_state)
# Plot loss
plt.figure()
plt.plot(model.loss_log, lw=2)
plt.yscale('log')
plt.xlabel('Iter #')
plt.ylabel('Loss')
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in broadcast_shapes(*shapes)
#     120   try:
# --> 121     return _broadcast_shapes_cached(*shapes)
#     122   except:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     209       else:
# --> 210         return cached(config._trace_context(), *args, **kwargs)
#     211
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     202     def cached(_, *args, **kwargs):
# --> 203       return f(*args, **kwargs)
#     204
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_cached(*shapes)
#     126 def _broadcast_shapes_cached(*shapes: Tuple[int, ...]) -> Tuple[int, ...]:
# --> 127   return _broadcast_shapes_uncached(*shapes)
#     128
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     143     raise ValueError("Incompatible shapes for broadcasting: {}"
# --> 144                      .format(tuple(shape_list)))
#     145   return result_shape
#
# ValueError: Incompatible shapes for broadcasting: ((1, 1, 128, 10), (128, 1, 1, 512))
#
# During handling of the above exception, another exception occurred:
#
# UnfilteredStackTrace                      Traceback (most recent call last)
# <ipython-input-29-30c306a250c1> in <module>()
#       1 # Train model
# ----> 2 model.train(train_dataset, nIter=5000)
#       3 opt_params = model.get_params(model.opt_state)
#
# <ipython-input-22-4a40b786ad24> in train(self, dataset, nIter)
#      36             batch = next(data)
# ---> 37             self.opt_state = self.step(next(self.itercount), self.opt_state, batch)
#      38             if it % 50 == 0:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     161     try:
# --> 162       return fun(*args, **kwargs)
#     163     except Exception as e:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     434         device=device, backend=backend, name=flat_fun.__name__,
# --> 435         donated_invars=donated_invars, inline=inline)
#     436     out_pytree_def = out_tree()
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, fun, *args, **params)
#    1708   def bind(self, fun, *args, **params):
# -> 1709     return call_bind(self, fun, *args, **params)
#    1710
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1720   tracers = map(top_trace.full_raise, args)
# -> 1721   outs = top_trace.process_call(primitive, fun, tracers, params)
#    1722   return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     613   def process_call(self, primitive, f, tracers, params):
# --> 614     return primitive.impl(f, *tracers, **params)
#     615   process_map = process_call
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/dispatch.py in _xla_call_impl(***failed resolving arguments***)
#     142   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
# --> 143                                *unsafe_map(arg_spec, args))
#     144   try:
#
# /usr/local/lib/python3.7/dist-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     271     else:
# --> 272       ans = call(fun, *args)
#     273       cache[key] = (ans, fun.stores)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/dispatch.py in _xla_callable_uncached(fun, device, backend, name, donated_invars, *arg_specs)
#     169   return lower_xla_callable(fun, device, backend, name, donated_invars,
# --> 170                             *arg_specs).compile().unsafe_call
#     171
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     205     with TraceAnnotation(name, **decorator_kwargs):
# --> 206       return func(*args, **kwargs)
#     207     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/dispatch.py in lower_xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     197     jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(
# --> 198         fun, abstract_args, pe.debug_info_final(fun, "jit"))
#     199   if any(isinstance(c, core.Tracer) for c in consts):
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     205     with TraceAnnotation(name, **decorator_kwargs):
# --> 206       return func(*args, **kwargs)
#     207     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals, debug_info)
#    1797     with core.new_sublevel():
# -> 1798       jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1799     del fun, main
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs)
#    1774     in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 1775     ans = fun.call_wrapped(*in_tracers_)
#    1776     out_tracers = map(trace.full_raise, ans)
#
# /usr/local/lib/python3.7/dist-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#
# <ipython-input-22-4a40b786ad24> in step(self, i, opt_state, batch)
#      26         params = self.get_params(opt_state)
# ---> 27         gradients = grad(self.loss)(params, batch, i)
#      28         return self.opt_update(i, gradients, opt_state)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     161     try:
# --> 162       return fun(*args, **kwargs)
#     163     except Exception as e:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in grad_f(*args, **kwargs)
#     875   def grad_f(*args, **kwargs):
# --> 876     _, g = value_and_grad_f(*args, **kwargs)
#     877     return g
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     161     try:
# --> 162       return fun(*args, **kwargs)
#     163     except Exception as e:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in value_and_grad_f(*args, **kwargs)
#     951     if not has_aux:
# --> 952       ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#     953     else:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in _vjp(fun, has_aux, reduce_axes, *primals)
#    2408     out_primal, out_vjp = ad.vjp(
# -> 2409         flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2410     out_tree = out_tree()
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux, reduce_axes)
#     118   if not has_aux:
# --> 119     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     120   else:
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#     105   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 106   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#     107   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     205     with TraceAnnotation(name, **decorator_kwargs):
# --> 206       return func(*args, **kwargs)
#     207     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate)
#     591     fun = trace_to_subjaxpr(fun, main, instantiate)
# --> 592     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     593     assert not env
#
# /usr/local/lib/python3.7/dist-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#
# <ipython-input-22-4a40b786ad24> in loss(self, params, batch, it)
#      20         outputs = self.net_apply(params, images,rng=random.PRNGKey(it))
# ---> 21         loss = -labels*np.log(outputs+1e-7)
#      22         return np.mean(loss)
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in __mul__(self, other)
#     506   def __rsub__(self, other): return self.aval._rsub(self, other)
# --> 507   def __mul__(self, other): return self.aval._mul(self, other)
#     508   def __rmul__(self, other): return self.aval._rmul(self, other)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    5251       return NotImplemented
# -> 5252     return binary_op(self, other)
#    5253   return deferring_binary_op
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     161     try:
# --> 162       return fun(*args, **kwargs)
#     163     except Exception as e:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     434         device=device, backend=backend, name=flat_fun.__name__,
# --> 435         donated_invars=donated_invars, inline=inline)
#     436     out_pytree_def = out_tree()
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, fun, *args, **params)
#    1708   def bind(self, fun, *args, **params):
# -> 1709     return call_bind(self, fun, *args, **params)
#    1710
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1720   tracers = map(top_trace.full_raise, args)
# -> 1721   outs = top_trace.process_call(primitive, fun, tracers, params)
#    1722   return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     330                   if update_params else params)
# --> 331     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     332     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, fun, *args, **params)
#    1708   def bind(self, fun, *args, **params):
# -> 1709     return call_bind(self, fun, *args, **params)
#    1710
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1720   tracers = map(top_trace.full_raise, args)
# -> 1721   outs = top_trace.process_call(primitive, fun, tracers, params)
#    1722   return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in process_call(self, primitive, f, tracers, params)
#     206     # Run the call, getting known out vals and aux data used for staged-out call
# --> 207     out = primitive.bind(f, *in_consts, **const_params)
#     208     out_knowns, out_avals, jaxpr, env = aux()
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in bind(self, fun, *args, **params)
#    1708   def bind(self, fun, *args, **params):
# -> 1709     return call_bind(self, fun, *args, **params)
#    1710
#
# /usr/local/lib/python3.7/dist-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1720   tracers = map(top_trace.full_raise, args)
# -> 1721   outs = top_trace.process_call(primitive, fun, tracers, params)
#    1722   return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#    1505       jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
# -> 1506         f, self.main, in_avals, keep_inputs=keep_inputs)
#    1507     if params.get('inline', False):
#
# /usr/local/lib/python3.7/dist-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs)
#    1774     in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 1775     ans = fun.call_wrapped(*in_tracers_)
#    1776     out_tracers = map(trace.full_raise, ans)
#
# /usr/local/lib/python3.7/dist-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/ufuncs.py in fn(x1, x2)
#      85   def fn(x1, x2):
# ---> 86     x1, x2 = _promote_args(numpy_fn.__name__, x1, x2)
#      87     return lax_fn(x1, x2) if x1.dtype != np.bool_ else bool_lax_fn(x1, x2)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/util.py in _promote_args(fun_name, *args)
#     314   _check_no_float0s(fun_name, *args)
# --> 315   return _promote_shapes(fun_name, *_promote_dtypes(*args))
#     316
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/util.py in _promote_shapes(fun_name, *args)
#     223       else:
# --> 224         result_rank = len(lax.broadcast_shapes(*shapes))
#     225         return [_broadcast_to(arg, (1,) * (result_rank - len(shp)) + shp)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in broadcast_shapes(*shapes)
#     122   except:
# --> 123     return _broadcast_shapes_uncached(*shapes)
#     124
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     143     raise ValueError("Incompatible shapes for broadcasting: {}"
# --> 144                      .format(tuple(shape_list)))
#     145   return result_shape
#
# UnfilteredStackTrace: ValueError: Incompatible shapes for broadcasting: ((1, 1, 128, 10), (128, 1, 1, 512))
#
# The stack trace below excludes JAX-internal frames.
# The preceding is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-30c306a250c1> in <module>()
#       1 # Train model
# ----> 2 model.train(train_dataset, nIter=5000)
#       3 opt_params = model.get_params(model.opt_state)
#       4 # Plot loss
#       5 plt.figure()
#
# <ipython-input-22-4a40b786ad24> in train(self, dataset, nIter)
#      35             # Run one gradient descent update
#      36             batch = next(data)
# ---> 37             self.opt_state = self.step(next(self.itercount), self.opt_state, batch)
#      38             if it % 50 == 0:
#      39                 # Logger
#
# <ipython-input-22-4a40b786ad24> in step(self, i, opt_state, batch)
#      25     def step(self, i, opt_state, batch):
#      26         params = self.get_params(opt_state)
# ---> 27         gradients = grad(self.loss)(params, batch, i)
#      28         return self.opt_update(i, gradients, opt_state)
#      29
#
# <ipython-input-22-4a40b786ad24> in loss(self, params, batch, it)
#      19         images, labels = batch
#      20         outputs = self.net_apply(params, images,rng=random.PRNGKey(it))
# ---> 21         loss = -labels*np.log(outputs+1e-7)
#      22         return np.mean(loss)
#      23
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    5250     if not isinstance(other, _accepted_binop_types):
#    5251       return NotImplemented
# -> 5252     return binary_op(self, other)
#    5253   return deferring_binary_op
#    5254
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/ufuncs.py in fn(x1, x2)
#      84 def _maybe_bool_binop(numpy_fn, lax_fn, bool_lax_fn, lax_doc=False):
#      85   def fn(x1, x2):
# ---> 86     x1, x2 = _promote_args(numpy_fn.__name__, x1, x2)
#      87     return lax_fn(x1, x2) if x1.dtype != np.bool_ else bool_lax_fn(x1, x2)
#      88   fn = jit(fn, inline=True)
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/util.py in _promote_args(fun_name, *args)
#     313   _check_arraylike(fun_name, *args)
#     314   _check_no_float0s(fun_name, *args)
# --> 315   return _promote_shapes(fun_name, *_promote_dtypes(*args))
#     316
#     317
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/util.py in _promote_shapes(fun_name, *args)
#     222         return [_broadcast_to(arg, res_shape) for arg, shp in zip(args, shapes)]
#     223       else:
# --> 224         result_rank = len(lax.broadcast_shapes(*shapes))
#     225         return [_broadcast_to(arg, (1,) * (result_rank - len(shp)) + shp)
#     226                 for arg, shp in zip(args, shapes)]
#
# ValueError: Incompatible shapes for broadcasting: ((1, 1, 128, 10), (128, 1, 1, 512))

# %%
# Compute classification accuracy on the entire test data-set
@jit
def accuracy(params, batch):
    images, labels = batch
    outputs = model.predict(params, images)
    pred_class = np.argmax(outputs,1)
    true_class = np.argmax(labels,1)
    return np.sum((pred_class == true_class)) / images.shape[0]

acc = accuracy(opt_params, (x_test, y_test))
print('Classification accuracy: {}%'.format(100*acc))
